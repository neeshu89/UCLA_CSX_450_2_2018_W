# %%
source('../src/load_data.r')
source('../src/multiplot.r')

# %%
dim(housing_df)
# Out:
# [1] 1451   80

# %%
head(housing_df)
# Out:
#   MSSubClass MSZoning LotFrontage LotArea LotShape LandContour Utilities
# 1 60         RL       65           8450   Reg      Lvl         AllPub
# 2 20         RL       80           9600   Reg      Lvl         AllPub
# 3 60         RL       68          11250   IR1      Lvl         AllPub
# 4 70         RL       60           9550   IR1      Lvl         AllPub
# 5 60         RL       84          14260   IR1      Lvl         AllPub
# 6 50         RL       85          14115   IR1      Lvl         AllPub
#   LotConfig LandSlope Neighborhood ⋯ PoolArea PoolQC  Fence   MiscFeature
# 1 Inside    Gtl       CollgCr      ⋯ 0        without without without
# 2 FR2       Gtl       Veenker      ⋯ 0        without without without
# 3 Inside    Gtl       CollgCr      ⋯ 0        without without without
# 4 Corner    Gtl       Crawfor      ⋯ 0        without without without
# 5 FR2       Gtl       NoRidge      ⋯ 0        without without without
# ...

# %%
count_empty_total()

# %%
numeric_features = colnames(Filter(is.numeric, housing_df))
numeric_features
# Out:
#  [1] "LotFrontage"   "LotArea"       "YearBuilt"     "YearRemodAdd"
#  [5] "MasVnrArea"    "BsmtFinSF1"    "BsmtFinSF2"    "BsmtUnfSF"
#  [9] "TotalBsmtSF"   "FirstFlrSF"    "SecondFlrSF"   "LowQualFinSF"
# [13] "GrLivArea"     "GarageYrBlt"   "GarageArea"    "WoodDeckSF"
# [17] "OpenPorchSF"   "EnclosedPorch" "ThreeSsnPorch" "ScreenPorch"
# [21] "PoolArea"      "MiscVal"       "YrSold"        "SalePrice"

# %%
cor(Filter(is.numeric, housing_df))['SalePrice',]
# Out:
#   LotFrontage       LotArea     YearBuilt  YearRemodAdd    MasVnrArea
#    0.33334280    0.26466822    0.52327380    0.50748805    0.47748622
#    BsmtFinSF1    BsmtFinSF2     BsmtUnfSF   TotalBsmtSF    FirstFlrSF
#    0.38399461   -0.01034983    0.21570728    0.61329929    0.60696866
#   SecondFlrSF  LowQualFinSF     GrLivArea   GarageYrBlt    GarageArea
#    0.32283963   -0.02527687    0.71007310    0.47006287    0.62248357
#    WoodDeckSF   OpenPorchSF EnclosedPorch ThreeSsnPorch   ScreenPorch
#    0.32465849    0.31124359   -0.12882600    0.04523452    0.11301692
#      PoolArea       MiscVal        YrSold     SalePrice
#    0.09310180   -0.02096108   -0.02616478    1.00000000

# %%
factor_features = colnames(Filter(is.factor, housing_df))
factor_features
# Out:
#  [1] "MSSubClass"    "MSZoning"      "LotShape"      "LandContour"
#  [5] "Utilities"     "LotConfig"     "LandSlope"     "Neighborhood"
#  [9] "Condition1"    "Condition2"    "BldgType"      "HouseStyle"
# [13] "Street"        "Alley"         "OverallQual"   "OverallCond"
# [17] "RoofStyle"     "RoofMatl"      "Exterior1st"   "Exterior2nd"
# [21] "MasVnrType"    "ExterQual"     "ExterCond"     "Foundation"
# [25] "BsmtQual"      "BsmtCond"      "BsmtExposure"  "BsmtFinType1"
# [29] "BsmtFinType2"  "Heating"       "HeatingQC"     "CentralAir"
# [33] "Electrical"    "BsmtFullBath"  "BsmtHalfBath"  "FullBath"
# [37] "HalfBath"      "BedroomAbvGr"  "KitchenAbvGr"  "KitchenQual"
# [41] "TotRmsAbvGrd"  "Functional"    "Fireplaces"    "FireplaceQu"
# [45] "GarageType"    "GarageFinish"  "GarageCars"    "GarageQual"
# [49] "GarageCond"    "PavedDrive"    "PoolQC"        "Fence"
# [53] "MiscFeature"   "MoSold"        "SaleType"      "SaleCondition"

# %%
attach(housing_df)

# %%
boxplot(SalePrice - GrLivArea ~ MSSubClass)
# Out:
# plot without title

# %%
ms_sub_class = as.integer(MSSubClass)
plot(GrLivArea, SalePrice, pch = ms_sub_class, col =  ms_sub_class)
# Out:
# plot without title

# %%
boxplot(SalePrice - GrLivArea ~ Neighborhood)
# Out:
# plot without title

# %%
neighborhood = as.integer(Neighborhood)
plot(GrLivArea, SalePrice, pch = neighborhood, col =  neighborhood)
# Out:
# plot without title

# %%
mo_sold = as.integer(MoSold)
plot(GrLivArea, SalePrice, pch = mo_sold, col =  mo_sold)
# Out:
# plot without title

# %%
garage = as.integer(GarageCars)
plot(GrLivArea, SalePrice, pch = garage, col =  garage)
# Out:
# plot without title

# %%
roof_style = as.integer(SaleType)
plot(GrLivArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
roof_style = as.integer(GarageType)
plot(GrLivArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
roof_style = as.integer(YrSold-2006)
plot(GrLivArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
roof_style = as.integer(GarageType)
plot(LotArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
roof_style = as.integer(MSSubClass)
plot(LotArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
roof_style = as.integer(Fireplaces)
plot(GrLivArea, SalePrice, pch = roof_style, col =  roof_style)
# Out:
# plot without title

# %%
table(Fireplaces)
# Out:
# Fireplaces
#   0   1   2   3
# 685 648 113   5
